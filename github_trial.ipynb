# %% [markdown]
# <a href="https://colab.research.google.com/github/prakritii-i/ASCIIPlayer/blob/master/github_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello there")
# Out:
# hello there
